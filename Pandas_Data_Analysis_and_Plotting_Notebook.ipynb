# %%
import pandas as pd

# %%
df = pd.read_csv("/content/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 632          633         1       1   Stahelin-Maeglin, Dr. Max  male  32.0
# 91            92         0       3  Andreasson, Mr. Paul Edvin  male  20.0
# 105          106         0       3       Mionoff, Mr. Stoytcho  male  28.0
# 525          526         0       3          Farrell, Mr. James  male  40.5
# 762          763         1       3       Barah, Mr. Hanna Assi  male  20.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 632      0      0   13214  30.5000   B50        C
# 91       0      0  347466   7.8542   NaN        S
# 105      0      0  349207   7.8958   NaN        S
# 525      0      0  367232   7.7500   NaN        Q
# 762      0      0    2663   7.2292   NaN        C

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size
# Out:
# 10692

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Cabin"].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Sex"].nunique()
# Out:
# 2

# %%
df.sort_values(by="Age")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(by="Age", ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.rename(columns={"Sex": "Gender", "Pclass": "passenger_Class"}, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.rename(columns={"Sex": "Gender", "Pclass": "passenger_Class"}, inplace=False)
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId          0
# Survived             0
# passenger_Class      0
# Name                 0
# Gender               0
# Age                177
# SibSp                0
# Parch                0
# Ticket               0
# Fare                 0
# Cabin              687
# Embarked             2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("output.csv", index=False)

# %%
df
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived  passenger_Class         Age       SibSp  \
# count   891.000000  891.000000       891.000000  714.000000  891.000000
# mean    446.000000    0.383838         2.308642   29.699118    0.523008
# std     257.353842    0.486592         0.836071   14.526497    1.102743
# min       1.000000    0.000000         1.000000    0.420000    0.000000
# 25%     223.500000    0.000000         2.000000   20.125000    0.000000
# 50%     446.000000    0.000000         3.000000   28.000000    0.000000
# 75%     668.500000    1.000000         3.000000   38.000000    1.000000
# max     891.000000    1.000000         3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df["Age"].median()
# Out:
# 28.0

# %%
df["Age"].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].idxmax()
# Out:
# 630

# %%
df["Age"].std()
# Out:
# 14.526497332334044

# %%
df["Age"].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
df["Age"].hist()
# Out:
# <Axes: >

# %%
df.describe(include='object')
# Out:
#                        Name Gender  Ticket Cabin Embarked
# count                   891    891     891   204      889
# unique                  891      2     681   147        3
# top     Dooley, Mr. Patrick   male  347082    G6        S
# freq                      1    577       7     4      644

# %%
df["Gender"].mode()
# Out:
# 0    male
# Name: Gender, dtype: object

# %%
df["Gender"].value_counts()
# Out:
# Gender
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Gender"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Gender"].nunique()
# Out:
# 2

# %% [markdown]
# # Boolean / Conditional Filtering in Pandas

# %%
df[df["Age"] > 30]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 1              2         1                1
# 3              4         1                1
# 4              5         0                3
# 6              7         0                1
# 11            12         1                1
# ..           ...       ...              ...
# 873          874         0                3
# 879          880         1                1
# 881          882         0                3
# 885          886         0                3
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
df.loc[df["Age"] > 30, ["Name", "Age", "Fare"]]
# Out:
#                                                   Name   Age     Fare
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 4                             Allen, Mr. William Henry  35.0   8.0500
# 6                              McCarthy, Mr. Timothy J  54.0  51.8625
# 11                            Bonnell, Miss. Elizabeth  58.0  26.5500
# ..                                                 ...   ...      ...
# 873                        Vander Cruyssen, Mr. Victor  47.0   9.0000
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0  83.1583
# 881                                 Markun, Mr. Johann  33.0   7.8958
# 885               Rice, Mrs. William (Margaret Norton)  39.0  29.1250
# 890                                Dooley, Mr. Patrick  32.0   7.7500
#
# [305 rows x 3 columns]

# %%
df[(df["Age"] > 30) & (df["Fare"] > 50)]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 1              2         1                1
# 3              4         1                1
# 6              7         0                1
# 35            36         0                1
# 52            53         1                1
# ..           ...       ...              ...
# 838          839         1                3
# 856          857         1                1
# 867          868         0                1
# 871          872         1                1
# 879          880         1                1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ...

# %%
df[(df["Age"] > 30) | (df["Fare"] > 50)]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 1              2         1                1
# 3              4         1                1
# 4              5         0                3
# 6              7         0                1
# 11            12         1                1
# ..           ...       ...              ...
# 873          874         0                3
# 879          880         1                1
# 881          882         0                3
# 885          886         0                3
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
df[df["Embarked"].isin(["C", "S"])]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 884          885         0                3
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df[~df["Embarked"].isin(["C", "S"])]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 5              6         0                3
# 16            17         0                3
# 22            23         1                3
# 28            29         1                3
# 32            33         1                3
# ..           ...       ...              ...
# 825          826         0                3
# 828          829         1                3
# 829          830         1                1
# 885          886         0                3
# 890          891         0                3
#
#                                           Name  Gender   Age  SibSp  Parch  \
# 5                             Moran, Mr. James    male   NaN      0      0
# 16                        Rice, Master. Eugene    male   2.0      4      1
# 22                 McGowan, Miss. Anna "Annie"  female  15.0      0      0
# 28               O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0      0
# ...

# %%
df[df["Age"].between(20, 30)]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 2              3         1                3
# 8              9         1                3
# 12            13         0                3
# 23            24         1                1
# ..           ...       ...              ...
# 882          883         0                3
# 883          884         0                2
# 884          885         0                3
# 886          887         0                2
# 889          890         1                1
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# ...

# %%
df[df["Age"].isnull()]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 5              6         0                3
# 17            18         1                2
# 19            20         1                3
# 26            27         0                3
# 28            29         1                3
# ..           ...       ...              ...
# 859          860         0                3
# 863          864         0                3
# 868          869         0                3
# 878          879         0                3
# 888          889         0                3
#
#                                          Name  Gender  Age  SibSp  Parch  \
# 5                            Moran, Mr. James    male  NaN      0      0
# 17               Williams, Mr. Charles Eugene    male  NaN      0      0
# 19                    Masselmani, Mrs. Fatima  female  NaN      0      0
# 26                    Emir, Mr. Farred Chehab    male  NaN      0      0
# ...

# %%
df[df["Age"].notnull()]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 885          886         0                3
# 886          887         0                2
# 887          888         1                1
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df[df["Name"].str.contains("John")]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 1              2         1                1
# 8              9         1                3
# 41            42         0                2
# 45            46         0                3
# 98            99         1                2
# 112          113         0                3
# 117          118         0                2
# 160          161         0                3
# 162          163         0                3
# 165          166         1                3
# 168          169         0                1
# 172          173         1                3
# 188          189         0                3
# 212          213         0                3
# 226          227         1                2
# 227          228         0                3
# 302          303         0                3
# 324          325         0                3
# 328          329         1                3
# 401          402         0                3
# ...

# %%
df[df["Name"].str.startswith("A")]
# Out:
#      PassengerId  Survived  passenger_Class  \
# 4              5         0                3
# 13            14         0                3
# 25            26         1                3
# 40            41         0                3
# 49            50         0                3
# 68            69         1                3
# 91            92         0                3
# 114          115         0                3
# 119          120         0                3
# 144          145         0                2
# 146          147         1                3
# 182          183         0                3
# 192          193         1                3
# 207          208         1                3
# 210          211         0                3
# 233          234         1                3
# 244          245         0                3
# 261          262         1                3
# 275          276         1                1
# 279          280         1                3
# ...

# %%
df.query("Age > 30 and Fare > 50")
# Out:
#      PassengerId  Survived  passenger_Class  \
# 1              2         1                1
# 3              4         1                1
# 6              7         0                1
# 35            36         0                1
# 52            53         1                1
# ..           ...       ...              ...
# 838          839         1                3
# 856          857         1                1
# 867          868         0                1
# 871          872         1                1
# 879          880         1                1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ...

# %%
df.loc[df["Age"] < 18, "Category"] = "Child"

# %%
df
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.groupby("Gender")

# %%
df.groupby("Gender")["Age"].mean()
# Out:
# Gender
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby("Gender")["Fare"].sum()
# Out:
# Gender
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
df.groupby("Gender")["Age"].count()
# Out:
# Gender
# female    261
# male      453
# Name: Age, dtype: int64

# %%
df.groupby("Gender")["Age"].agg(["mean", "min", "max"])
# Out:
#              mean   min   max
# Gender
# female  27.915709  0.75  63.0
# male    30.726645  0.42  80.0

# %%
df.groupby(["Gender", "passenger_Class"])["Fare"].mean()
# Out:
# Gender  passenger_Class
# female  1                  106.125798
#         2                   21.970121
#         3                   16.118810
# male    1                   67.226127
#         2                   19.741782
#         3                   12.661633
# Name: Fare, dtype: float64

# %%
df.groupby("Gender")["Age"].mean().reset_index()
# Out:
#    Gender        Age
# 0  female  27.915709
# 1    male  30.726645

# %%
df.groupby("Gender").agg(
    avg_age=("Age", "mean"),
    max_fare=("Fare", "max")
)
# Out:
#           avg_age  max_fare
# Gender
# female  27.915709  512.3292
# male    30.726645  512.3292

# %%
df.groupby("Gender").filter(lambda x: x["Age"].mean() > 30)
# Out:
#      PassengerId  Survived  passenger_Class                            Name  \
# 0              1         0                3         Braund, Mr. Owen Harris
# 4              5         0                3        Allen, Mr. William Henry
# 5              6         0                3                Moran, Mr. James
# 6              7         0                1         McCarthy, Mr. Timothy J
# 7              8         0                3  Palsson, Master. Gosta Leonard
# ..           ...       ...              ...                             ...
# 883          884         0                2   Banfield, Mr. Frederick James
# 884          885         0                3          Sutehall, Mr. Henry Jr
# 886          887         0                2           Montvila, Rev. Juozas
# 889          890         1                1           Behr, Mr. Karl Howell
# 890          891         0                3             Dooley, Mr. Patrick
#
# ...

# %%
df["mean_age_by_gender"] = df.groupby("Gender")["Age"].transform("mean")

# %%
df
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.sort_values(by="Age")
# Out:
#      PassengerId  Survived  passenger_Class  \
# 803          804         1                3
# 755          756         1                2
# 644          645         1                3
# 469          470         1                3
# 78            79         1                2
# ..           ...       ...              ...
# 859          860         0                3
# 863          864         0                3
# 868          869         0                3
# 878          879         0                3
# 888          889         0                3
#
#                                          Name  Gender   Age  SibSp  Parch  \
# 803           Thomas, Master. Assad Alexander    male  0.42      0      1
# 755                 Hamalainen, Master. Viljo    male  0.67      1      1
# 644                    Baclini, Miss. Eugenie  female  0.75      2      1
# 469             Baclini, Miss. Helene Barbara  female  0.75      2      1
# ...

# %%
df.sort_values(by=["Gender", "Age"])
# Out:
#      PassengerId  Survived  passenger_Class  \
# 469          470         1                3
# 644          645         1                3
# 172          173         1                3
# 381          382         1                3
# 119          120         0                3
# ..           ...       ...              ...
# 839          840         1                1
# 846          847         0                3
# 859          860         0                3
# 868          869         0                3
# 878          879         0                3
#
#                                   Name  Gender   Age  SibSp  Parch    Ticket  \
# 469      Baclini, Miss. Helene Barbara  female  0.75      2      1      2666
# 644             Baclini, Miss. Eugenie  female  0.75      2      1      2666
# 172       Johnson, Miss. Eleanor Ileen  female  1.00      1      1    347742
# 381        Nakid, Miss. Maria ("Mary")  female  1.00      0      2      2653
# ...

# %%
df.sort_index()
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.groupby("passenger_Class")["Fare"].mean().sort_values(ascending=False)
# Out:
# passenger_Class
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.nlargest(5, "Fare")
# Out:
#      PassengerId  Survived  passenger_Class  \
# 258          259         1                1
# 679          680         1                1
# 737          738         1                1
# 27            28         0                1
# 88            89         1                1
#
#                                    Name  Gender   Age  SibSp  Parch    Ticket  \
# 258                    Ward, Miss. Anna  female  35.0      0      0  PC 17755
# 679  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0      1  PC 17755
# 737              Lesurer, Mr. Gustave J    male  35.0      0      0  PC 17755
# 27       Fortune, Mr. Charles Alexander    male  19.0      3      2     19950
# 88           Fortune, Miss. Mabel Helen  female  23.0      3      2     19950
#
#          Fare        Cabin Embarked Category  mean_age_by_gender
# 258  512.3292          NaN        C      NaN           27.915709
# 679  512.3292  B51 B53 B55        C      NaN           30.726645
# ...

# %%
df.nsmallest(5, "Age")
# Out:
#      PassengerId  Survived  passenger_Class                             Name  \
# 803          804         1                3  Thomas, Master. Assad Alexander
# 755          756         1                2        Hamalainen, Master. Viljo
# 469          470         1                3    Baclini, Miss. Helene Barbara
# 644          645         1                3           Baclini, Miss. Eugenie
# 78            79         1                2    Caldwell, Master. Alden Gates
#
#      Gender   Age  SibSp  Parch  Ticket     Fare Cabin Embarked Category  \
# 803    male  0.42      0      1    2625   8.5167   NaN        C    Child
# 755    male  0.67      1      1  250649  14.5000   NaN        S    Child
# 469  female  0.75      2      1    2666  19.2583   NaN        C    Child
# 644  female  0.75      2      1    2666  19.2583   NaN        C    Child
# 78     male  0.83      0      2  248738  29.0000   NaN        S    Child
#
#      mean_age_by_gender
# 803           30.726645
# ...

# %%
df.groupby("passenger_Class")["Fare"].mean().sort_values(ascending=False)
# Out:
# passenger_Class
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.groupby(["Gender", "passenger_Class"])["Age"].mean().reset_index()
# Out:
#    Gender  passenger_Class        Age
# 0  female                1  34.611765
# 1  female                2  28.722973
# 2  female                3  21.750000
# 3    male                1  41.281386
# 4    male                2  30.740707
# 5    male                3  26.507589

# %%
df.isnull().sum()
# Out:
# PassengerId             0
# Survived                0
# passenger_Class         0
# Name                    0
# Gender                  0
# Age                   177
# SibSp                   0
# Parch                   0
# Ticket                  0
# Fare                    0
# Cabin                 687
# Embarked                2
# Category              778
# mean_age_by_gender      0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# PassengerId           0.000000
# Survived              0.000000
# passenger_Class       0.000000
# Name                  0.000000
# Gender                0.000000
# Age                   0.198653
# SibSp                 0.000000
# Parch                 0.000000
# Ticket                0.000000
# Fare                  0.000000
# Cabin                 0.771044
# Embarked              0.002245
# Category              0.873176
# mean_age_by_gender    0.000000
# dtype: float64

# %%
df["Age"].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
df["Age"].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_9259/1698716155.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# /tmp/ipykernel_9259/1933487976.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  passenger_Class  \
# 0            1         0                3
# 1            2         1                1
# 2            3         1                3
# 3            4         1                1
# 4            5         0                3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Category  \
# 0      0         A/5 21171   7.2500   NaN        S      NaN
# 1      0          PC 17599  71.2833   C85        C      NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S      NaN
# ...

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_9259/3744086084.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  passenger_Class  \
# 0            1         0                3
# 1            2         1                1
# 2            3         1                3
# 3            4         1                1
# 4            5         0                3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Category  \
# 0      0         A/5 21171   7.2500   NaN        S      NaN
# 1      0          PC 17599  71.2833   C85        C      NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S      NaN
# ...

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  passenger_Class  \
# 0            1         0                3
# 1            2         1                1
# 2            3         1                3
# 3            4         1                1
# 4            5         0                3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked Category  mean_age_by_gender
# 0      0         A/5 21171   7.2500        S      NaN           30.726645
# 1      0          PC 17599  71.2833        C      NaN           27.915709
# ...

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#     PassengerId  Survived  passenger_Class  \
# 7             8         0                3
# 9            10         1                2
# 10           11         1                3
# 14           15         0                3
# 16           17         0                3
#
#                                     Name  Gender   Age  SibSp  Parch   Ticket  \
# 7         Palsson, Master. Gosta Leonard    male   2.0      3      1   349909
# 9    Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0   237736
# 10       Sandstrom, Miss. Marguerite Rut  female   4.0      1      1  PP 9549
# 14  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0      0   350406
# 16                  Rice, Master. Eugene    male   2.0      4      1   382652
#
#        Fare Embarked Category  mean_age_by_gender
# 7   21.0750        S    Child           30.726645
# 9   30.0708        C    Child           27.915709
# 10  16.7000        S    Child           27.915709
# ...

# %%
df.drop("Age", axis=1, inplace=True)

# %%
df.head()
# Out:
#     PassengerId  Survived  passenger_Class  \
# 7             8         0                3
# 9            10         1                2
# 10           11         1                3
# 14           15         0                3
# 16           17         0                3
#
#                                     Name  Gender  SibSp  Parch   Ticket  \
# 7         Palsson, Master. Gosta Leonard    male      3      1   349909
# 9    Nasser, Mrs. Nicholas (Adele Achem)  female      1      0   237736
# 10       Sandstrom, Miss. Marguerite Rut  female      1      1  PP 9549
# 14  Vestrom, Miss. Hulda Amanda Adolfina  female      0      0   350406
# 16                  Rice, Master. Eugene    male      4      1   382652
#
#        Fare Embarked Category  mean_age_by_gender
# 7   21.0750        S    Child           30.726645
# 9   30.0708        C    Child           27.915709
# 10  16.7000        S    Child           27.915709
# 14   7.8542        S    Child           27.915709
# ...

# %%
df
# Out:
#      PassengerId  Survived  passenger_Class  \
# 7              8         0                3
# 9             10         1                2
# 10            11         1                3
# 14            15         0                3
# 16            17         0                3
# ..           ...       ...              ...
# 850          851         0                3
# 852          853         0                3
# 853          854         1                1
# 869          870         1                3
# 875          876         1                3
#
#                                         Name  Gender  SibSp  Parch    Ticket  \
# 7             Palsson, Master. Gosta Leonard    male      3      1    349909
# 9        Nasser, Mrs. Nicholas (Adele Achem)  female      1      0    237736
# 10           Sandstrom, Miss. Marguerite Rut  female      1      1   PP 9549
# 14      Vestrom, Miss. Hulda Amanda Adolfina  female      0      0    350406
# ...

# %%
import seaborn as sns
sns.histplot(df["Ticket_Fare"])
# Out:
# <Axes: xlabel='Ticket_Fare', ylabel='Count'>

# %%
df["Ticket_Fare"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
x = df.index
y = df['Ticket_Fare']
plt.plot(x, y)
plt.show()

# %%
sns.histplot(df["Ticket_Fare"])
# Out:
# <Axes: xlabel='Ticket_Fare', ylabel='Count'>

# %%
sns.countplot(x=df["Gender"])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.scatterplot(x="mean_age_by_gender", y="Ticket_Fare", data=df)
# Out:
# <Axes: xlabel='mean_age_by_gender', ylabel='Ticket_Fare'>

# %%
sns.lineplot(x="mean_age_by_gender", y="Ticket_Fare", data=df)
# Out:
# <Axes: xlabel='mean_age_by_gender', ylabel='Ticket_Fare'>

# %%
sns.boxplot(x="Gender", y="Ticket_Fare", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Ticket_Fare'>

# %%
sns.violinplot(x="Gender", y="Ticket_Fare", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Ticket_Fare'>

# %%
sns.barplot(x="Gender", y="Ticket_Fare", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Ticket_Fare'>

# %%
sns.countplot(x="Gender", hue="Survived", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
pd.crosstab(df["Gender"], df["Survived"])
# Out:
# Survived   0   1
# Gender
# female    17  38
# male      35  23

# %%
pd.crosstab(df["Gender"], df["Survived"], normalize="index") * 100
# Out:
# Survived          0          1
# Gender
# female    30.909091  69.090909
# male      60.344828  39.655172

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 110          111         0       1           Porter, Mr. Walter Chamberlain
# 478          479         0       3                Karlsson, Mr. Nils August
# 530          531         1       2                 Quick, Miss. Phyllis May
# 665          666         0       2                       Hickman, Mr. Lewis
# 310          311         1       1           Hays, Miss. Margaret Bechstein
# 119          120         0       3        Andersson, Miss. Ellis Anna Maria
# 63            64         0       3                    Skoog, Master. Harald
# 274          275         1       3               Healy, Miss. Hanora "Nora"
# 472          473         1       2  West, Mrs. Edwy Arthur (Ada Mary Worth)
# 818          819         0       3         Holm, Mr. John Fredrik Alexander
#
#         Sex   Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
len(df)
# Out:
# 891

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Age"].isnull().sample(10)
# Out:
# 507     True
# 797    False
# 578     True
# 639     True
# 443    False
# 72     False
# 796    False
# 89     False
# 549    False
# 731    False
# Name: Age, dtype: bool

# %%
name = "rasidul hoque chowdhury"
name.strip().title()
# Out:
# 'Rasidul Hoque Chowdhury'

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
[df['Embarked'].isnull() == True]
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  886    False
#  887    False
#  888    False
#  889    False
#  890    False
#  Name: Embarked, Length: 891, dtype: bool]

# %%
df["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.Sex == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df[df["Sex"] == "male"]["Sex"].count()
# Out:
# np.int64(577)

# %%
891 - 577
# Out:
# 314

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.Age.argmax()
# Out:
# np.int64(630)

# %%
df.iloc[630]
# Out:
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Sex                                            male
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# Name: 630, dtype: object

# %%
df[df["Sex"] =='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Age"] < 13) & (df["Sex"] == "male")]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 78            79         1       2
# 125          126         1       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 182          183         0       3
# 183          184         1       2
# 193          194         1       2
# 261          262         1       3
# 278          279         0       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 386          387         0       3
# 407          408         1       2
# 445          446         1       1
# 480          481         0       3
# 489          490         1       3
# 549          550         1       2
# 731          732         0       3
# ...

# %%
df[(df['Age'] < 10) & (df['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 58            59         1       2              West, Miss. Constance Mirium
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 147          148         0       3          Ford, Miss. Robina Maggie "Ruby"
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 184          185         1       3       Kink-Heilmann, Miss. Luise Gretchen
# 205          206         0       3                Strom, Miss. Telma Matilda
# 233          234         1       3            Asplund, Miss. Lillian Gertrud
# 237          238         1       2          Collyer, Miss. Marjorie "Lottie"
# ...

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Age"].median()
# Out:
# 28.0

# %%
import numpy as np
np.median(np.array([20, 22, 27, 32, 28, 90]))
# Out:
# np.float64(27.5)

# %%
df["Embarked"].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df[df.Embarked.isnull() == True]
df.Embarked.fillna(df.Embarked.mode()[0],inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df.Survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df[["Survived", "Pclass", "Age"]]
# Out:
#      Survived  Pclass   Age
# 0           0       3  22.0
# 1           1       1  38.0
# 2           1       3  26.0
# 3           1       1  35.0
# 4           0       3  35.0
# ..        ...     ...   ...
# 886         0       2  27.0
# 887         1       1  19.0
# 888         0       3   NaN
# 889         1       1  26.0
# 890         0       3  32.0
#
# [891 rows x 3 columns]

# %%
df.iloc[3:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 3      0  113803  53.1000  C123        S
# ...

# %%
df.loc[0:10, ["Survived", "Pclass"]]
# Out:
#     Survived  Pclass
# 0          0       3
# 1          1       1
# 2          1       3
# 3          1       1
# 4          0       3
# 5          0       3
# 6          0       1
# 7          0       3
# 8          1       3
# 9          1       2
# 10         1       3

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df.loc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
d = [{"name": "Saihan", "Age": 20}, {"name": "Sadia", "Age": 30}]

df1 = pd.DataFrame(d)

df1
# Out:
#      name  Age
# 0  Saihan   20
# 1   Sadia   30

# %%
df1.loc[0, "name"] = "Saihan Ahmed"

# %%
df1
# Out:
#      name  Age
# 0  Saihan   20
# 1   Sadia   30

# %%
df[['name','Age']].sample(n=2)
# Out:
#            name  Age
# 0  Saihan Ahmed   20
# 1         Sadia   30
