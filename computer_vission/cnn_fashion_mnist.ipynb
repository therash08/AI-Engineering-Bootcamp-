# %% [markdown]
# # Table of Contents
# - Intro to Computer Vision and CNN `(Check Slide and Class Video)`
# - CNN Fashion MNIST Classification

# %% [markdown]
# # 👔 Fashion Product Classification using Artificial Neural Network
#
# ![](https://www.researchgate.net/profile/Saeed-Reza-Kheradpisheh/publication/342801790/figure/fig2/AS:911232181735425@1594266090934/Sample-images-from-Fashion-MNIST-dataset.png)

# %%
pip install numpy pandas matplotlib seaborn scikit-learn scipy jupyter notebook ipykernel plotly tensorflow keras opencv-python pillow tqdm pydot
# Out:
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (2.4.4)
# Requirement already satisfied: pandas in .\.venv\Lib\site-packages (3.0.5)
# Requirement already satisfied: matplotlib in .\.venv\Lib\site-packages (3.11.1)
# Requirement already satisfied: seaborn in .\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in .\.venv\Lib\site-packages (1.9.0)
# Requirement already satisfied: scipy in .\.venv\Lib\site-packages (1.18.0)
# Requirement already satisfied: jupyter in .\.venv\Lib\site-packages (1.1.1)
# Requirement already satisfied: notebook in .\.venv\Lib\site-packages (7.6.1)
# Requirement already satisfied: ipykernel in .\.venv\Lib\site-packages (7.3.0)
# Requirement already satisfied: plotly in .\.venv\Lib\site-packages (6.9.0)
# Requirement already satisfied: tensorflow in .\.venv\Lib\site-packages (2.21.0)
# Requirement already satisfied: keras in .\.venv\Lib\site-packages (3.15.0)
# Requirement already satisfied: opencv-python in .\.venv\Lib\site-packages (5.0.0.93)
# Requirement already satisfied: pillow in .\.venv\Lib\site-packages (12.2.0)
# Requirement already satisfied: tqdm in .\.venv\Lib\site-packages (4.69.0)
# Requirement already satisfied: pydot in .\.venv\Lib\site-packages (4.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in .\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: joblib>=1.4.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in .\.venv\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in .\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: jupyter-console in .\.venv\Lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in .\.venv\Lib\site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: ipywidgets in .\.venv\Lib\site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in .\.venv\Lib\site-packages (from jupyter) (4.6.2)
# Requirement already satisfied: jupyter-builder<2,>=1.0.2 in .\.venv\Lib\site-packages (from notebook) (1.1.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in .\.venv\Lib\site-packages (from notebook) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in .\.venv\Lib\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in .\.venv\Lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in .\.venv\Lib\site-packages (from notebook) (6.5.7)
# Requirement already satisfied: jupyter-core in .\.venv\Lib\site-packages (from jupyter-builder<2,>=1.0.2->notebook) (5.9.1)
# Requirement already satisfied: traitlets in .\.venv\Lib\site-packages (from jupyter-builder<2,>=1.0.2->notebook) (5.15.1)
# Requirement already satisfied: anyio>=3.1.0 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (4.14.2)
# Requirement already satisfied: argon2-cffi>=21.1 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (8.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (0.25.0)
# Requirement already satisfied: pywinpty!=3.0.4,>=2.0.1 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (3.0.5)
# Requirement already satisfied: pyzmq>=24 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in .\.venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in .\.venv\Lib\site-packages (from jupyterlab->jupyter) (2.3.1)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in .\.venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.18)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: babel>=2.10 in .\.venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in .\.venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in .\.venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: requests>=2.31 in .\.venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.34.2)
# Requirement already satisfied: comm>=0.1.1 in .\.venv\Lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in .\.venv\Lib\site-packages (from ipykernel) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in .\.venv\Lib\site-packages (from ipykernel) (9.15.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in .\.venv\Lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in .\.venv\Lib\site-packages (from ipykernel) (1.7.2)
# Requirement already satisfied: psutil>=5.7 in .\.venv\Lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: absl-py>=1.0.0 in .\.venv\Lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in .\.venv\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in .\.venv\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in .\.venv\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in .\.venv\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in .\.venv\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in .\.venv\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in .\.venv\Lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: setuptools in .\.venv\Lib\site-packages (from tensorflow) (78.1.0)
# Requirement already satisfied: six>=1.12.0 in .\.venv\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in .\.venv\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in .\.venv\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in .\.venv\Lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in .\.venv\Lib\site-packages (from tensorflow) (1.83.0)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in .\.venv\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in .\.venv\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.7.0)
# Requirement already satisfied: rich in .\.venv\Lib\site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in .\.venv\Lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in .\.venv\Lib\site-packages (from keras) (0.19.1)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: argon2-cffi-bindings in .\.venv\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->notebook) (25.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in .\.venv\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: decorator>=5.1.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in .\.venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in .\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in .\.venv\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.19.0->notebook) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2026.6.3)
# Requirement already satisfied: platformdirs>=2.5 in .\.venv\Lib\site-packages (from jupyter-core->jupyter-builder<2,>=1.0.2->notebook) (4.11.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in .\.venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in .\.venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in .\.venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in .\.venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in .\.venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in .\.venv\Lib\site-packages (from nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in .\.venv\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.4.0)
# Requirement already satisfied: defusedxml in .\.venv\Lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in .\.venv\Lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in .\.venv\Lib\site-packages (from nbconvert->jupyter) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in .\.venv\Lib\site-packages (from nbconvert->jupyter) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in .\.venv\Lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in .\.venv\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in .\.venv\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in .\.venv\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->notebook) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in .\.venv\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.2)
# Requirement already satisfied: pure-eval in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in .\.venv\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->notebook) (2.1.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->notebook) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\.venv\Lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.9.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\.venv\Lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\.venv\Lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: arrow>=0.15.0 in .\.venv\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->notebook) (1.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ## 📥 2. Load Fashion MNIST Dataset

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

print(x_train.shape)  # (60000, 28, 28)
print(y_train.shape)

print(x_test.shape)  # (10000, 28, 28)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
# Label mapper

idx_to_label = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %% [markdown]
# ## 🎨 3. Visualization of Sample Data

# %%
plt.figure(figsize=(10, 4))

for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f"Label: {idx_to_label[y_train[i]]}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Data Preprocessing (Normalization)
#
# ![](https://lh3.googleusercontent.com/proxy/wNLhUqpOpBGPmfUIopgsshTtyJHh8VnAl5Ef4Koz9vXhLQ5osTQBwi5dTV-SbeL7NV6mRN_bOM8OO2bFL8Np3AQQTjdKm3Qb5MNhmB3Ts0E954BJJl-cjHp5f1c6znVIahNpuA)

# %%
print(f"Max pixel value before Normalization: {x_train.max()}")
print(f"Min pixel value before Normalization: {x_train.min()}")

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

print(f"Max pixel value after Normalization: {x_train.max()}")
print(f"Min pixel value after Normalization: {x_train.min()}")
# Out:
# Max pixel value before Normalization: 255
# Min pixel value before Normalization: 0
# Max pixel value after Normalization: 1.0
# Min pixel value after Normalization: 0.0

# %%
print(f"Train data shape before reshaping: {x_train.shape}")
print(f"Test data shape before reshaping: {x_test.shape}")

# CNN expects:
# (batch, height, width, channel)

x_train = x_train[..., np.newaxis]
x_test = x_test[..., np.newaxis]

print(f"Train data shape after reshaping: {x_train.shape}")
print(f"Test data shape after reshaping: {x_test.shape}")
# Out:
# Train data shape before reshaping: (60000, 28, 28)
# Test data shape before reshaping: (10000, 28, 28)
# Train data shape after reshaping: (60000, 28, 28, 1)
# Test data shape after reshaping: (10000, 28, 28, 1)

# %% [markdown]
# ## 🏗️ 5. Build CNN Model
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRnBcx-4BZBEEc2MVTHnmI4w-I_Sn5eQSl0sHidUP3llFy7dDL6BCgrmg8&s=10)

# %%
model = models.Sequential([

    layers.Input(shape=(28,28,1)),

    # Feature extraction
    layers.Conv2D(filters=32, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),

    layers.Conv2D(filters=64,kernel_size=(3,3),activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),

    # Converting 2d/3d data into 1d
    layers.Flatten(),

    # Fully Connected Layer
    layers.Dense(128, activation="relu"),

    # Classification -> 10 category
    layers.Dense(units=10, activation="softmax")

])

# %%
from tensorflow.keras.utils import plot_model

plot_model(
    model,
    to_file='neural_network_plot.png',
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir='LR', # 'TB' for top-to-bottom layout; 'LR' for left-to-right layout
    show_layer_activations=True
)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# # ⚙️ 6. Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 🚀 7. Train Model

# %%
history = model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8152 - loss: 0.5169 - val_accuracy: 0.8632 - val_loss: 0.3751
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8772 - loss: 0.3394 - val_accuracy: 0.8891 - val_loss: 0.3103
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8945 - loss: 0.2916 - val_accuracy: 0.8957 - val_loss: 0.2906
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9061 - loss: 0.2582 - val_accuracy: 0.9050 - val_loss: 0.2649
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9135 - loss: 0.2339 - val_accuracy: 0.9047 - val_loss: 0.2587
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9223 - loss: 0.2120 - val_accuracy: 0.9035 - val_loss: 0.2790
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9297 - loss: 0.1919 - val_accuracy: 0.9094 - val_loss: 0.2482
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9358 - loss: 0.1726 - val_accuracy: 0.9107 - val_loss: 0.2491
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9408 - loss: 0.1570 - val_accuracy: 0.9123 - val_loss: 0.2530
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9482 - loss: 0.1408 - val_accuracy: 0.9159 - val_loss: 0.2404

# %% [markdown]
# # 📈 8. Training Visualization

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title("Accuracy")
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title("Loss")
plt.legend()

plt.show()

# %% [markdown]
# # 🔮 9. Predictions Visualization

# %%
predictions = model.predict(x_test)

plt.figure(figsize=(10, 6))

for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(x_test[i].reshape(28,28), cmap='gray')
    pred_label = np.argmax(predictions[i])
    true_label = y_test[i]
    plt.title(f"Pred:{idx_to_label[pred_label]} \nTrue:{idx_to_label[true_label]}",
              fontsize=10
    )
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# # 📊 10. Evaluate Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9103 - loss: 0.2537
# Test Accuracy: 0.9103000164031982

# %%
y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)


print("\n📊 Classification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# 📊 Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86      1000
#            1       0.99      0.98      0.98      1000
#            2       0.88      0.84      0.86      1000
#            3       0.90      0.91      0.91      1000
#            4       0.83      0.90      0.86      1000
#            5       0.99      0.97      0.98      1000
#            6       0.77      0.71      0.74      1000
#            7       0.94      0.98      0.96      1000
#            8       0.97      0.98      0.98      1000
#            9       0.98      0.95      0.97      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000

# %% [markdown]
# # 11. Error Analysis

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)


cm = confusion_matrix(
    y_test,
    y_pred
)


plt.figure(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    xticklabels=idx_to_label.values(),
    yticklabels=idx_to_label.values()
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Get predictions
predictions = model.predict(x_test)

# Convert probabilities to labels
pred_labels = np.argmax(predictions, axis=1)


# Find wrong predictions
errors = np.where(pred_labels != y_test)[0]


print("Total errors:", len(errors))


# Visualize wrong predictions
plt.figure(figsize=(12, 8))

for i, idx in enumerate(errors[:20]):   # show first 20 mistakes

    plt.subplot(4, 5, i+1)

    plt.imshow(
        x_test[idx].reshape(28,28),
        cmap='gray'
    )

    pred_label = pred_labels[idx]
    true_label = y_test[idx]

    plt.title(
        f"Pred:{idx_to_label[pred_label]}\nTrue:{idx_to_label[true_label]}",
        fontsize=10
    )

    plt.axis('off')


plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Total errors: 897

# %% [markdown]
# # 12. Saving the Model

# %%
model_name = "cnn_fashion_mnist_with_batchnorm.h5"

model.save(model_name)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loaded_model = tf.keras.models.load_model(model_name)
print("Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!
